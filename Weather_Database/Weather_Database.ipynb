# %%
#Import our dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pprint

#Import your Requests Library and the weather_api_key.
import requests
from config import weather_api_key

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy


# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
#Loop through the cities list.

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 771

# %%
#Initialize an Empty List and Counters

#Build the basic URL for the OpenWeatherMap with your weather_api_key added to the URL.
#Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
#print(url)

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
#Group the cities in sets of 50 to log the process as we find the weather data for each city.
# Loop through all the cities in the list.
for i, city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
        
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    
    # Add 1 to the record count.
    record_count += 1
    
    #Build the city_url or endpoint for each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    #Make an API request for each city.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse the JSON weather data for the following:
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})
        #"Current Description": city_description
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | thompson
# Processing Record 2 of Set 1 | upernavik
# Processing Record 3 of Set 1 | dzerzhinsk
# Processing Record 4 of Set 1 | cabo san lucas
# Processing Record 5 of Set 1 | busselton
# Processing Record 6 of Set 1 | rindal
# Processing Record 7 of Set 1 | filingue
# Processing Record 8 of Set 1 | hermanus
# Processing Record 9 of Set 1 | hamilton
# Processing Record 10 of Set 1 | cody
# Processing Record 11 of Set 1 | kapaa
# Processing Record 12 of Set 1 | waipawa
# Processing Record 13 of Set 1 | mataura
# Processing Record 14 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 15 of Set 1 | albany
# Processing Record 16 of Set 1 | skalistyy
# City not found. Skipping...
# Processing Record 17 of Set 1 | punta arenas
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | dujuma
# City not found. Skipping...
# Processing Record 20 of Set 1 | katsuura
# Processing Record 21 of Set 1 | campos altos
# Processing Record 22 of Set 1 | camacha
# Processing Record 23 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 24 of Set 1 | jumla
# Processing Record 25 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 26 of Set 1 | santa rosa
# Processing Record 27 of Set 1 | castro
# Processing Record 28 of Set 1 | asfi
# Processing Record 29 of Set 1 | berlevag
# Processing Record 30 of Set 1 | norman wells
# Processing Record 31 of Set 1 | port alfred
# Processing Record 32 of Set 1 | avarua
# Processing Record 33 of Set 1 | la libertad
# Processing Record 34 of Set 1 | vaini
# Processing Record 35 of Set 1 | tambura
# Processing Record 36 of Set 1 | verkhnyaya inta
# Processing Record 37 of Set 1 | alyangula
# Processing Record 38 of Set 1 | kudahuvadhoo
# Processing Record 39 of Set 1 | keller
# Processing Record 40 of Set 1 | maragogi
# Processing Record 41 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 42 of Set 1 | san patricio
# Processing Record 43 of Set 1 | ribeira grande
# Processing Record 44 of Set 1 | alofi
# Processing Record 45 of Set 1 | vanimo
# Processing Record 46 of Set 1 | bethel
# Processing Record 47 of Set 1 | starotimoshkino
# Processing Record 48 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 49 of Set 1 | marsh harbour
# Processing Record 50 of Set 1 | yellowknife
# Processing Record 1 of Set 2 | tukrah
# Processing Record 2 of Set 2 | tura
# Processing Record 3 of Set 2 | gumdag
# Processing Record 4 of Set 2 | cherskiy
# Processing Record 5 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 6 of Set 2 | chuy
# Processing Record 7 of Set 2 | tasiilaq
# Processing Record 8 of Set 2 | rikitea
# Processing Record 9 of Set 2 | hasaki
# Processing Record 10 of Set 2 | kavieng
# Processing Record 11 of Set 2 | akyab
# Processing Record 12 of Set 2 | nazilli
# Processing Record 13 of Set 2 | nikolskoye
# Processing Record 14 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 15 of Set 2 | pevek
# Processing Record 16 of Set 2 | new norfolk
# Processing Record 17 of Set 2 | dingle
# Processing Record 18 of Set 2 | poum
# Processing Record 19 of Set 2 | bulancak
# Processing Record 20 of Set 2 | barrow
# Processing Record 21 of Set 2 | acapulco
# Processing Record 22 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 23 of Set 2 | maceio
# Processing Record 24 of Set 2 | hobart
# Processing Record 25 of Set 2 | touros
# Processing Record 26 of Set 2 | mackenzie
# Processing Record 27 of Set 2 | ostrovnoy
# Processing Record 28 of Set 2 | destin
# Processing Record 29 of Set 2 | narsaq
# Processing Record 30 of Set 2 | bredasdorp
# Processing Record 31 of Set 2 | longyearbyen
# Processing Record 32 of Set 2 | liverpool
# Processing Record 33 of Set 2 | moyale
# Processing Record 34 of Set 2 | achisay
# City not found. Skipping...
# Processing Record 35 of Set 2 | inirida
# Processing Record 36 of Set 2 | suda
# Processing Record 37 of Set 2 | damghan
# Processing Record 38 of Set 2 | tessalit
# Processing Record 39 of Set 2 | khatanga
# Processing Record 40 of Set 2 | saint-philippe
# Processing Record 41 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 42 of Set 2 | tomari
# Processing Record 43 of Set 2 | nemuro
# Processing Record 44 of Set 2 | severo-yeniseyskiy
# Processing Record 45 of Set 2 | chabahar
# Processing Record 46 of Set 2 | san cristobal
# Processing Record 47 of Set 2 | trimbak
# Processing Record 48 of Set 2 | dikson
# Processing Record 49 of Set 2 | yarmouth
# Processing Record 50 of Set 2 | danville
# Processing Record 1 of Set 3 | derzhavinsk
# Processing Record 2 of Set 3 | qaanaaq
# Processing Record 3 of Set 3 | severo-kurilsk
# Processing Record 4 of Set 3 | avinurme
# Processing Record 5 of Set 3 | sangmelima
# Processing Record 6 of Set 3 | saint-ambroise
# Processing Record 7 of Set 3 | guerrero negro
# Processing Record 8 of Set 3 | aranos
# Processing Record 9 of Set 3 | saskylakh
# Processing Record 10 of Set 3 | codrington
# Processing Record 11 of Set 3 | wanaka
# Processing Record 12 of Set 3 | xaxim
# Processing Record 13 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 14 of Set 3 | victoria
# Processing Record 15 of Set 3 | kieta
# Processing Record 16 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 17 of Set 3 | atuona
# Processing Record 18 of Set 3 | gambela
# Processing Record 19 of Set 3 | lakes entrance
# Processing Record 20 of Set 3 | bogovarovo
# Processing Record 21 of Set 3 | garowe
# Processing Record 22 of Set 3 | port elizabeth
# Processing Record 23 of Set 3 | fort dodge
# Processing Record 24 of Set 3 | sivaki
# Processing Record 25 of Set 3 | lorengau
# Processing Record 26 of Set 3 | cayenne
# Processing Record 27 of Set 3 | viransehir
# Processing Record 28 of Set 3 | rafsanjan
# Processing Record 29 of Set 3 | praia da vitoria
# Processing Record 30 of Set 3 | lasa
# Processing Record 31 of Set 3 | sayyan
# Processing Record 32 of Set 3 | mar del plata
# Processing Record 33 of Set 3 | bathurst
# Processing Record 34 of Set 3 | puerto ayora
# Processing Record 35 of Set 3 | san pedro
# Processing Record 36 of Set 3 | phalodi
# Processing Record 37 of Set 3 | havre-saint-pierre
# Processing Record 38 of Set 3 | unye
# City not found. Skipping...
# Processing Record 39 of Set 3 | oktyabrskiy
# Processing Record 40 of Set 3 | jamestown
# Processing Record 41 of Set 3 | kibala
# Processing Record 42 of Set 3 | butaritari
# Processing Record 43 of Set 3 | bluff
# Processing Record 44 of Set 3 | maputo
# Processing Record 45 of Set 3 | muros
# Processing Record 46 of Set 3 | vao
# Processing Record 47 of Set 3 | fukue
# Processing Record 48 of Set 3 | bengkulu
# Processing Record 49 of Set 3 | charters towers
# Processing Record 50 of Set 3 | santa fe
# Processing Record 1 of Set 4 | hobyo
# Processing Record 2 of Set 4 | bara
# Processing Record 3 of Set 4 | hithadhoo
# Processing Record 4 of Set 4 | lavrentiya
# Processing Record 5 of Set 4 | dalvik
# Processing Record 6 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 7 of Set 4 | west odessa
# Processing Record 8 of Set 4 | agua dulce
# Processing Record 9 of Set 4 | ust-karsk
# Processing Record 10 of Set 4 | hilo
# Processing Record 11 of Set 4 | smithers
# Processing Record 12 of Set 4 | lompoc
# Processing Record 13 of Set 4 | port lincoln
# Processing Record 14 of Set 4 | ahipara
# Processing Record 15 of Set 4 | sorong
# Processing Record 16 of Set 4 | saldanha
# Processing Record 17 of Set 4 | iqaluit
# Processing Record 18 of Set 4 | pangnirtung
# Processing Record 19 of Set 4 | yandoon
# City not found. Skipping...
# Processing Record 20 of Set 4 | caohai
# Processing Record 21 of Set 4 | port lavaca
# Processing Record 22 of Set 4 | pokosnoye
# Processing Record 23 of Set 4 | kruisfontein
# Processing Record 24 of Set 4 | yulara
# Processing Record 25 of Set 4 | eureka
# Processing Record 26 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record 27 of Set 4 | labuhan
# Processing Record 28 of Set 4 | cape town
# Processing Record 29 of Set 4 | luis correia
# Processing Record 30 of Set 4 | necochea
# Processing Record 31 of Set 4 | chokurdakh
# Processing Record 32 of Set 4 | parabel
# Processing Record 33 of Set 4 | klaksvik
# Processing Record 34 of Set 4 | ponta do sol
# Processing Record 35 of Set 4 | rio gallegos
# Processing Record 36 of Set 4 | hirara
# Processing Record 37 of Set 4 | ostersund
# Processing Record 38 of Set 4 | greenville
# Processing Record 39 of Set 4 | boueni
# Processing Record 40 of Set 4 | barra dos coqueiros
# Processing Record 41 of Set 4 | port hardy
# Processing Record 42 of Set 4 | sitka
# Processing Record 43 of Set 4 | petauke
# Processing Record 44 of Set 4 | bowen
# Processing Record 45 of Set 4 | rexburg
# Processing Record 46 of Set 4 | davidson
# Processing Record 47 of Set 4 | gravdal
# Processing Record 48 of Set 4 | lensk
# Processing Record 49 of Set 4 | ilinge
# Processing Record 50 of Set 4 | olafsvik
# Processing Record 1 of Set 5 | popondetta
# Processing Record 2 of Set 5 | shimanovsk
# Processing Record 3 of Set 5 | san jose de las lajas
# Processing Record 4 of Set 5 | tuktoyaktuk
# Processing Record 5 of Set 5 | mount isa
# Processing Record 6 of Set 5 | benguela
# Processing Record 7 of Set 5 | tuatapere
# Processing Record 8 of Set 5 | muli
# Processing Record 9 of Set 5 | timmins
# Processing Record 10 of Set 5 | lumut
# Processing Record 11 of Set 5 | darhan
# Processing Record 12 of Set 5 | poltavka
# Processing Record 13 of Set 5 | vershino-shakhtaminskiy
# Processing Record 14 of Set 5 | quepos
# Processing Record 15 of Set 5 | caranavi
# Processing Record 16 of Set 5 | georgetown
# Processing Record 17 of Set 5 | halifax
# Processing Record 18 of Set 5 | saint george
# Processing Record 19 of Set 5 | ayagoz
# Processing Record 20 of Set 5 | hovd
# Processing Record 21 of Set 5 | isangel
# Processing Record 22 of Set 5 | olavarria
# Processing Record 23 of Set 5 | kichera
# Processing Record 24 of Set 5 | gravelbourg
# Processing Record 25 of Set 5 | lipari
# Processing Record 26 of Set 5 | male
# Processing Record 27 of Set 5 | nanortalik
# Processing Record 28 of Set 5 | cidreira
# Processing Record 29 of Set 5 | carnarvon
# Processing Record 30 of Set 5 | ilulissat
# Processing Record 31 of Set 5 | iralaya
# Processing Record 32 of Set 5 | punta gorda
# Processing Record 33 of Set 5 | pisco
# Processing Record 34 of Set 5 | saint-pierre
# Processing Record 35 of Set 5 | nara
# Processing Record 36 of Set 5 | constitucion
# Processing Record 37 of Set 5 | clyde river
# Processing Record 38 of Set 5 | rongcheng
# Processing Record 39 of Set 5 | comodoro rivadavia
# Processing Record 40 of Set 5 | awbari
# Processing Record 41 of Set 5 | talnakh
# Processing Record 42 of Set 5 | vedea
# Processing Record 43 of Set 5 | port-gentil
# Processing Record 44 of Set 5 | provideniya
# Processing Record 45 of Set 5 | namibe
# Processing Record 46 of Set 5 | torbay
# Processing Record 47 of Set 5 | puerto colombia
# Processing Record 48 of Set 5 | kaitangata
# Processing Record 49 of Set 5 | tautira
# Processing Record 50 of Set 5 | ayan
# Processing Record 1 of Set 6 | kenora
# Processing Record 2 of Set 6 | padang
# Processing Record 3 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 4 of Set 6 | abu samrah
# Processing Record 5 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 6 of Set 6 | flin flon
# Processing Record 7 of Set 6 | khonuu
# City not found. Skipping...
# Processing Record 8 of Set 6 | airai
# Processing Record 9 of Set 6 | ayer itam
# City not found. Skipping...
# Processing Record 10 of Set 6 | yumen
# Processing Record 11 of Set 6 | surat
# Processing Record 12 of Set 6 | aklavik
# Processing Record 13 of Set 6 | sonoita
# Processing Record 14 of Set 6 | kroya
# Processing Record 15 of Set 6 | saint-francois
# Processing Record 16 of Set 6 | lagoa
# Processing Record 17 of Set 6 | pasighat
# Processing Record 18 of Set 6 | mount gambier
# Processing Record 19 of Set 6 | springbok
# Processing Record 20 of Set 6 | beloomut
# Processing Record 21 of Set 6 | berezovyy
# Processing Record 22 of Set 6 | gilazi
# City not found. Skipping...
# Processing Record 23 of Set 6 | el monte
# Processing Record 24 of Set 6 | slave lake
# Processing Record 25 of Set 6 | dese
# Processing Record 26 of Set 6 | fairbanks
# Processing Record 27 of Set 6 | evensk
# Processing Record 28 of Set 6 | lanas
# Processing Record 29 of Set 6 | sivas
# Processing Record 30 of Set 6 | souillac
# Processing Record 31 of Set 6 | araouane
# Processing Record 32 of Set 6 | mariental
# Processing Record 33 of Set 6 | tombouctou
# Processing Record 34 of Set 6 | demba
# Processing Record 35 of Set 6 | verkhnetulomskiy
# Processing Record 36 of Set 6 | lewisporte
# Processing Record 37 of Set 6 | geraldton
# Processing Record 38 of Set 6 | east london
# Processing Record 39 of Set 6 | entre rios
# Processing Record 40 of Set 6 | alexandria
# Processing Record 41 of Set 6 | iraucuba
# Processing Record 42 of Set 6 | seoul
# Processing Record 43 of Set 6 | freeport
# Processing Record 44 of Set 6 | esso
# Processing Record 45 of Set 6 | lawrenceburg
# Processing Record 46 of Set 6 | monrovia
# Processing Record 47 of Set 6 | hambantota
# Processing Record 48 of Set 6 | ormara
# Processing Record 49 of Set 6 | tabou
# Processing Record 50 of Set 6 | arraial do cabo
# Processing Record 1 of Set 7 | koshurnikovo
# Processing Record 2 of Set 7 | north platte
# Processing Record 3 of Set 7 | ugoofaaru
# Processing Record 4 of Set 7 | les cayes
# Processing Record 5 of Set 7 | bambous virieux
# Processing Record 6 of Set 7 | praya
# Processing Record 7 of Set 7 | husavik
# Processing Record 8 of Set 7 | basoko
# Processing Record 9 of Set 7 | bacolod
# Processing Record 10 of Set 7 | ibotirama
# Processing Record 11 of Set 7 | vila velha
# Processing Record 12 of Set 7 | whitehorse
# Processing Record 13 of Set 7 | jhelum
# Processing Record 14 of Set 7 | talaya
# Processing Record 15 of Set 7 | la ronge
# Processing Record 16 of Set 7 | shimoda
# Processing Record 17 of Set 7 | svetlogorsk
# Processing Record 18 of Set 7 | metro
# Processing Record 19 of Set 7 | walvis bay
# Processing Record 20 of Set 7 | punta alta
# Processing Record 21 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 22 of Set 7 | srednekolymsk
# Processing Record 23 of Set 7 | teya
# Processing Record 24 of Set 7 | moose factory
# Processing Record 25 of Set 7 | bontang
# Processing Record 26 of Set 7 | bay roberts
# Processing Record 27 of Set 7 | beringovskiy
# Processing Record 28 of Set 7 | nong kung si
# Processing Record 29 of Set 7 | esperance
# Processing Record 30 of Set 7 | savinka
# Processing Record 31 of Set 7 | dunedin
# Processing Record 32 of Set 7 | nisia floresta
# Processing Record 33 of Set 7 | biak
# Processing Record 34 of Set 7 | meadow lake
# Processing Record 35 of Set 7 | gat
# Processing Record 36 of Set 7 | svetlaya
# Processing Record 37 of Set 7 | fortuna
# Processing Record 38 of Set 7 | pulivendla
# Processing Record 39 of Set 7 | bima
# Processing Record 40 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 41 of Set 7 | tiksi
# Processing Record 42 of Set 7 | cartagena
# Processing Record 43 of Set 7 | la romana
# Processing Record 44 of Set 7 | badiraguato
# Processing Record 45 of Set 7 | lima
# Processing Record 46 of Set 7 | ahuimanu
# Processing Record 47 of Set 7 | burtunay
# Processing Record 48 of Set 7 | atbasar
# Processing Record 49 of Set 7 | xai-xai
# Processing Record 50 of Set 7 | nortelandia
# Processing Record 1 of Set 8 | vestmannaeyjar
# Processing Record 2 of Set 8 | srandakan
# Processing Record 3 of Set 8 | rajshahi
# Processing Record 4 of Set 8 | verkhoturye
# Processing Record 5 of Set 8 | samal
# Processing Record 6 of Set 8 | rurrenabaque
# Processing Record 7 of Set 8 | uwayl
# City not found. Skipping...
# Processing Record 8 of Set 8 | rumford
# Processing Record 9 of Set 8 | kloulklubed
# Processing Record 10 of Set 8 | grand gaube
# Processing Record 11 of Set 8 | manavalakurichi
# Processing Record 12 of Set 8 | san quintin
# Processing Record 13 of Set 8 | mantua
# Processing Record 14 of Set 8 | salalah
# Processing Record 15 of Set 8 | sao filipe
# Processing Record 16 of Set 8 | lichuan
# Processing Record 17 of Set 8 | erenhot
# Processing Record 18 of Set 8 | naze
# Processing Record 19 of Set 8 | tawnat
# City not found. Skipping...
# Processing Record 20 of Set 8 | diego de almagro
# Processing Record 21 of Set 8 | ferme-neuve
# Processing Record 22 of Set 8 | chapais
# Processing Record 23 of Set 8 | orlik
# Processing Record 24 of Set 8 | moron
# Processing Record 25 of Set 8 | asau
# Processing Record 26 of Set 8 | mandalgovi
# Processing Record 27 of Set 8 | dunda
# Processing Record 28 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 29 of Set 8 | mehamn
# Processing Record 30 of Set 8 | gondanglegi
# Processing Record 31 of Set 8 | tiznit
# Processing Record 32 of Set 8 | ilhabela
# Processing Record 33 of Set 8 | acobamba
# Processing Record 34 of Set 8 | sinkat
# City not found. Skipping...
# Processing Record 35 of Set 8 | komsomolskiy
# Processing Record 36 of Set 8 | lebu
# Processing Record 37 of Set 8 | burica
# City not found. Skipping...
# Processing Record 38 of Set 8 | acajutla
# Processing Record 39 of Set 8 | tonj
# Processing Record 40 of Set 8 | rocha
# Processing Record 41 of Set 8 | tutoia
# Processing Record 42 of Set 8 | hay river
# Processing Record 43 of Set 8 | kulhudhuffushi
# Processing Record 44 of Set 8 | broome
# Processing Record 45 of Set 8 | melbu
# Processing Record 46 of Set 8 | koronowo
# Processing Record 47 of Set 8 | madimba
# Processing Record 48 of Set 8 | kodiak
# Processing Record 49 of Set 8 | port macquarie
# Processing Record 50 of Set 8 | kachikau
# City not found. Skipping...
# Processing Record 1 of Set 9 | iwaki
# Processing Record 2 of Set 9 | gao
# Processing Record 3 of Set 9 | ternate
# Processing Record 4 of Set 9 | batamshinskiy
# Processing Record 5 of Set 9 | mahebourg
# Processing Record 6 of Set 9 | tanquian
# City not found. Skipping...
# Processing Record 7 of Set 9 | barkly west
# Processing Record 8 of Set 9 | baoshan
# Processing Record 9 of Set 9 | harlingen
# Processing Record 10 of Set 9 | nedjo
# Processing Record 11 of Set 9 | datong
# Processing Record 12 of Set 9 | conceicao do araguaia
# Processing Record 13 of Set 9 | manadhoo
# Processing Record 14 of Set 9 | vaitape
# Processing Record 15 of Set 9 | gwadar
# Processing Record 16 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 17 of Set 9 | stornoway
# Processing Record 18 of Set 9 | kahului
# Processing Record 19 of Set 9 | mumford
# Processing Record 20 of Set 9 | martil
# Processing Record 21 of Set 9 | kavaratti
# Processing Record 22 of Set 9 | sovetskiy
# Processing Record 23 of Set 9 | springdale
# Processing Record 24 of Set 9 | puerto cabezas
# Processing Record 25 of Set 9 | zachagansk
# City not found. Skipping...
# Processing Record 26 of Set 9 | yokadouma
# Processing Record 27 of Set 9 | hokitika
# Processing Record 28 of Set 9 | mitu
# Processing Record 29 of Set 9 | te anau
# Processing Record 30 of Set 9 | sillod
# Processing Record 31 of Set 9 | vardo
# Processing Record 32 of Set 9 | nouadhibou
# Processing Record 33 of Set 9 | boa vista
# Processing Record 34 of Set 9 | konevo
# Processing Record 35 of Set 9 | khandyga
# Processing Record 36 of Set 9 | hofn
# Processing Record 37 of Set 9 | akdepe
# Processing Record 38 of Set 9 | bilibino
# Processing Record 39 of Set 9 | honningsvag
# Processing Record 40 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 41 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 42 of Set 9 | mafinga
# Processing Record 43 of Set 9 | salinopolis
# Processing Record 44 of Set 9 | tynda
# Processing Record 45 of Set 9 | eresos
# Processing Record 46 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 47 of Set 9 | tongzi
# Processing Record 48 of Set 9 | jeremie
# Processing Record 49 of Set 9 | dongsheng
# Processing Record 50 of Set 9 | college
# Processing Record 1 of Set 10 | leningradskiy
# Processing Record 2 of Set 10 | porbandar
# Processing Record 3 of Set 10 | iracoubo
# Processing Record 4 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 5 of Set 10 | avera
# Processing Record 6 of Set 10 | salisbury
# Processing Record 7 of Set 10 | port blair
# Processing Record 8 of Set 10 | sumbawa
# City not found. Skipping...
# Processing Record 9 of Set 10 | corn island
# Processing Record 10 of Set 10 | witu
# Processing Record 11 of Set 10 | atocha
# Processing Record 12 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 13 of Set 10 | juegang
# Processing Record 14 of Set 10 | labrea
# Processing Record 15 of Set 10 | oistins
# Processing Record 16 of Set 10 | kracheh
# City not found. Skipping...
# Processing Record 17 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 18 of Set 10 | agadez
# Processing Record 19 of Set 10 | luderitz
# Processing Record 20 of Set 10 | ambon
# Processing Record 21 of Set 10 | palmer
# Processing Record 22 of Set 10 | high level
# Processing Record 23 of Set 10 | matara
# Processing Record 24 of Set 10 | isiro
# Processing Record 25 of Set 10 | goderich
# Processing Record 26 of Set 10 | tilichiki
# Processing Record 27 of Set 10 | muravlenko
# Processing Record 28 of Set 10 | landshut
# Processing Record 29 of Set 10 | mikuni
# Processing Record 30 of Set 10 | innisfail
# Processing Record 31 of Set 10 | carahue
# Processing Record 32 of Set 10 | esfarayen
# Processing Record 33 of Set 10 | tonantins
# Processing Record 34 of Set 10 | kaseda
# Processing Record 35 of Set 10 | ingham
# Processing Record 36 of Set 10 | mareeba
# Processing Record 37 of Set 10 | sept-iles
# Processing Record 38 of Set 10 | kendari
# Processing Record 39 of Set 10 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 40 of Set 10 | kichmengskiy gorodok
# Processing Record 41 of Set 10 | dekoa
# City not found. Skipping...
# Processing Record 42 of Set 10 | fagundes
# Processing Record 43 of Set 10 | henties bay
# Processing Record 44 of Set 10 | lata
# Processing Record 45 of Set 10 | nyagan
# Processing Record 46 of Set 10 | anchorage
# Processing Record 47 of Set 10 | sarakhs
# Processing Record 48 of Set 10 | gadsden
# Processing Record 49 of Set 10 | dongzhen
# Processing Record 50 of Set 10 | nuuk
# Processing Record 1 of Set 11 | zeya
# Processing Record 2 of Set 11 | temaraia
# City not found. Skipping...
# Processing Record 3 of Set 11 | marondera
# Processing Record 4 of Set 11 | coihaique
# Processing Record 5 of Set 11 | lishan
# Processing Record 6 of Set 11 | bereda
# Processing Record 7 of Set 11 | portoferraio
# Processing Record 8 of Set 11 | qarqin
# Processing Record 9 of Set 11 | piranshahr
# Processing Record 10 of Set 11 | puerto escondido
# Processing Record 11 of Set 11 | ondjiva
# Processing Record 12 of Set 11 | kaduqli
# Processing Record 13 of Set 11 | bac lieu
# Processing Record 14 of Set 11 | gizo
# Processing Record 15 of Set 11 | la asuncion
# Processing Record 16 of Set 11 | colombo
# Processing Record 17 of Set 11 | salinas
# Processing Record 18 of Set 11 | nuevo progreso
# Processing Record 19 of Set 11 | buala
# Processing Record 20 of Set 11 | kargasok
# Processing Record 21 of Set 11 | pecos
# Processing Record 22 of Set 11 | wulanhaote
# City not found. Skipping...
# Processing Record 23 of Set 11 | cockburn town
# Processing Record 24 of Set 11 | tricase
# Processing Record 25 of Set 11 | qaqortoq
# Processing Record 26 of Set 11 | tianmen
# Processing Record 27 of Set 11 | alice springs
# Processing Record 28 of Set 11 | concepcion del oro
# Processing Record 29 of Set 11 | yanam
# Processing Record 30 of Set 11 | flinders
# Processing Record 31 of Set 11 | shieli
# Processing Record 32 of Set 11 | joacaba
# Processing Record 33 of Set 11 | jalu
# Processing Record 34 of Set 11 | bira
# Processing Record 35 of Set 11 | makakilo city
# Processing Record 36 of Set 11 | banjar
# Processing Record 37 of Set 11 | lock haven
# Processing Record 38 of Set 11 | ola
# Processing Record 39 of Set 11 | bozoum
# Processing Record 40 of Set 11 | krasnoyarka
# Processing Record 41 of Set 11 | okhotsk
# Processing Record 42 of Set 11 | bam
# Processing Record 43 of Set 11 | yomitan
# City not found. Skipping...
# Processing Record 44 of Set 11 | igrim
# Processing Record 45 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 46 of Set 11 | ucluelet
# Processing Record 47 of Set 11 | blacksburg
# Processing Record 48 of Set 11 | myrtle beach
# Processing Record 49 of Set 11 | chirongui
# Processing Record 50 of Set 11 | korla
# Processing Record 1 of Set 12 | rawson
# Processing Record 2 of Set 12 | mahon
# Processing Record 3 of Set 12 | morondava
# Processing Record 4 of Set 12 | sindor
# Processing Record 5 of Set 12 | fairview
# Processing Record 6 of Set 12 | dayong
# Processing Record 7 of Set 12 | griffith
# Processing Record 8 of Set 12 | paamiut
# Processing Record 9 of Set 12 | mogadishu
# Processing Record 10 of Set 12 | zhezkazgan
# Processing Record 11 of Set 12 | abu kamal
# Processing Record 12 of Set 12 | teahupoo
# Processing Record 13 of Set 12 | krasnoye
# Processing Record 14 of Set 12 | itoman
# Processing Record 15 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 16 of Set 12 | egvekinot
# Processing Record 17 of Set 12 | horsham
# Processing Record 18 of Set 12 | bafra
# Processing Record 19 of Set 12 | namatanai
# Processing Record 20 of Set 12 | yar-sale
# Processing Record 21 of Set 12 | malinao
# Processing Record 22 of Set 12 | castelldefels
# Processing Record 23 of Set 12 | hirtshals
# Processing Record 24 of Set 12 | waingapu
# Processing Record 25 of Set 12 | vreed en hoop
# City not found. Skipping...
# Processing Record 26 of Set 12 | sorland
# Processing Record 27 of Set 12 | fushe-arrez
# Processing Record 28 of Set 12 | caraballeda
# Processing Record 29 of Set 12 | aguada de pasajeros
# Processing Record 30 of Set 12 | candawaga
# City not found. Skipping...
# Processing Record 31 of Set 12 | marzuq
# Processing Record 32 of Set 12 | smidovich
# Processing Record 33 of Set 12 | bacuit
# City not found. Skipping...
# Processing Record 34 of Set 12 | noyabrsk
# Processing Record 35 of Set 12 | plettenberg bay
# Processing Record 36 of Set 12 | kirakira
# Processing Record 37 of Set 12 | champerico
# Processing Record 38 of Set 12 | camana
# Processing Record 39 of Set 12 | japura
# Processing Record 40 of Set 12 | kabinda
# Processing Record 41 of Set 12 | afmadu
# City not found. Skipping...
# Processing Record 42 of Set 12 | acari
# Processing Record 43 of Set 12 | sechura
# Processing Record 44 of Set 12 | kalemie
# Processing Record 45 of Set 12 | iskateley
# Processing Record 46 of Set 12 | svecha
# Processing Record 47 of Set 12 | fuyang
# Processing Record 48 of Set 12 | honiara
# Processing Record 49 of Set 12 | hefei
# Processing Record 50 of Set 12 | anupgarh
# Processing Record 1 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 2 of Set 13 | nishihara
# Processing Record 3 of Set 13 | verkhnevilyuysk
# Processing Record 4 of Set 13 | progreso
# Processing Record 5 of Set 13 | kenai
# Processing Record 6 of Set 13 | coquimbo
# Processing Record 7 of Set 13 | uyuni
# Processing Record 8 of Set 13 | canchungo
# Processing Record 9 of Set 13 | lipin bor
# Processing Record 10 of Set 13 | sioux lookout
# Processing Record 11 of Set 13 | ulaangom
# Processing Record 12 of Set 13 | biloela
# Processing Record 13 of Set 13 | galle
# Processing Record 14 of Set 13 | antofagasta
# Processing Record 15 of Set 13 | domanivka
# Processing Record 16 of Set 13 | mahanje
# Processing Record 17 of Set 13 | herat
# Processing Record 18 of Set 13 | chegdomyn
# Processing Record 19 of Set 13 | sokol
# Processing Record 20 of Set 13 | safaga
# Processing Record 21 of Set 13 | chicama
# Processing Record 22 of Set 13 | da nang
# Processing Record 23 of Set 13 | banda aceh
# Processing Record 24 of Set 13 | salaga
# Processing Record 25 of Set 13 | faanui
# Processing Record 26 of Set 13 | tocopilla
# Processing Record 27 of Set 13 | valleyview
# Processing Record 28 of Set 13 | ixtapa
# Processing Record 29 of Set 13 | kuzino
# Processing Record 30 of Set 13 | takaka
# Processing Record 31 of Set 13 | bukavu
# Processing Record 32 of Set 13 | rio grande
# Processing Record 33 of Set 13 | khirkiya
# Processing Record 34 of Set 13 | bialong
# Processing Record 35 of Set 13 | bogalusa
# Processing Record 36 of Set 13 | winnemucca
# Processing Record 37 of Set 13 | cairns
# Processing Record 38 of Set 13 | san juan
# Processing Record 39 of Set 13 | tiarei
# Processing Record 40 of Set 13 | mahibadhoo
# Processing Record 41 of Set 13 | port-cartier
# Processing Record 42 of Set 13 | musoma
# Processing Record 43 of Set 13 | the valley
# Processing Record 44 of Set 13 | belaya kholunitsa
# Processing Record 45 of Set 13 | imbituba
# Processing Record 46 of Set 13 | petrykiv
# Processing Record 47 of Set 13 | sobolevo
# Processing Record 48 of Set 13 | makokou
# Processing Record 49 of Set 13 | san vicente
# Processing Record 50 of Set 13 | asyut
# Processing Record 1 of Set 14 | ust-kuyga
# Processing Record 2 of Set 14 | sedelnikovo
# City not found. Skipping...
# Processing Record 3 of Set 14 | shambu
# Processing Record 4 of Set 14 | havoysund
# Processing Record 5 of Set 14 | el faiyum
# City not found. Skipping...
# Processing Record 6 of Set 14 | marquette
# Processing Record 7 of Set 14 | kovdor
# Processing Record 8 of Set 14 | luganville
# Processing Record 9 of Set 14 | shilka
# Processing Record 10 of Set 14 | jiddah
# City not found. Skipping...
# Processing Record 11 of Set 14 | tarko-sale
# Processing Record 12 of Set 14 | olinda
# Processing Record 13 of Set 14 | aguia branca
# Processing Record 14 of Set 14 | bubaque
# Processing Record 15 of Set 14 | estepona
# Processing Record 16 of Set 14 | sulangan
# Processing Record 17 of Set 14 | kalga
# Processing Record 18 of Set 14 | portland
# Processing Record 19 of Set 14 | jabinyanah
# Processing Record 20 of Set 14 | sao raimundo nonato
# Processing Record 21 of Set 14 | barcelos
# Processing Record 22 of Set 14 | abu dhabi
# Processing Record 23 of Set 14 | gushikawa
# Processing Record 24 of Set 14 | calvinia
# Processing Record 25 of Set 14 | igarka
# Processing Record 26 of Set 14 | kattivakkam
# Processing Record 27 of Set 14 | puerto suarez
# Processing Record 28 of Set 14 | nome
# Processing Record 29 of Set 14 | vilhena
# Processing Record 30 of Set 14 | sola
# Processing Record 31 of Set 14 | bayan
# Processing Record 32 of Set 14 | le passage
# Processing Record 33 of Set 14 | cam ranh
# Processing Record 34 of Set 14 | rafai
# Processing Record 35 of Set 14 | anloga
# Processing Record 36 of Set 14 | teguldet
# Processing Record 37 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 38 of Set 14 | isahaya
# Processing Record 39 of Set 14 | port augusta
# Processing Record 40 of Set 14 | rucheng
# Processing Record 41 of Set 14 | paoua
# Processing Record 42 of Set 14 | northam
# Processing Record 43 of Set 14 | krasnyy chikoy
# Processing Record 44 of Set 14 | muswellbrook
# Processing Record 45 of Set 14 | sungaipenuh
# Processing Record 46 of Set 14 | tougue
# Processing Record 47 of Set 14 | viedma
# Processing Record 48 of Set 14 | malanville
# Processing Record 49 of Set 14 | nanakuli
# Processing Record 50 of Set 14 | karratha
# Processing Record 1 of Set 15 | kantabanji
# Processing Record 2 of Set 15 | lerwick
# Processing Record 3 of Set 15 | masakin
# Processing Record 4 of Set 15 | toropets
# Processing Record 5 of Set 15 | kimbe
# Processing Record 6 of Set 15 | kishtwar
# Processing Record 7 of Set 15 | cangzhou
# Processing Record 8 of Set 15 | broken hill
# Processing Record 9 of Set 15 | letterkenny
# Processing Record 10 of Set 15 | jacobina
# Processing Record 11 of Set 15 | bonthe
# Processing Record 12 of Set 15 | waw
# Processing Record 13 of Set 15 | songjianghe
# Processing Record 14 of Set 15 | soligalich
# Processing Record 15 of Set 15 | chaman
# Processing Record 16 of Set 15 | ponta delgada
# Processing Record 17 of Set 15 | worthington
# Processing Record 18 of Set 15 | rudnogorsk
# Processing Record 19 of Set 15 | chemax
# Processing Record 20 of Set 15 | raudeberg
# Processing Record 21 of Set 15 | kharan
# Processing Record 22 of Set 15 | quanzhou
# Processing Record 23 of Set 15 | birjand
# Processing Record 24 of Set 15 | muhos
# Processing Record 25 of Set 15 | pichayevo
# Processing Record 26 of Set 15 | navan
# Processing Record 27 of Set 15 | vila
# Processing Record 28 of Set 15 | vostok
# Processing Record 29 of Set 15 | strzelin
# Processing Record 30 of Set 15 | timra
# Processing Record 31 of Set 15 | great bend
# Processing Record 32 of Set 15 | kaifeng
# Processing Record 33 of Set 15 | zolotyy potik
# Processing Record 34 of Set 15 | calabozo
# Processing Record 35 of Set 15 | carballo
# Processing Record 36 of Set 15 | pemba
# Processing Record 37 of Set 15 | half moon bay
# Processing Record 38 of Set 15 | sinnamary
# Processing Record 39 of Set 15 | merauke
# Processing Record 40 of Set 15 | kuandian
# Processing Record 41 of Set 15 | zhigansk
# Processing Record 42 of Set 15 | vinkovci
# Processing Record 43 of Set 15 | synya
# Processing Record 44 of Set 15 | izazi
# Processing Record 45 of Set 15 | goure
# Processing Record 46 of Set 15 | roebourne
# Processing Record 47 of Set 15 | lucea
# Processing Record 48 of Set 15 | noumea
# Processing Record 49 of Set 15 | vila franca do campo
# Processing Record 50 of Set 15 | karanganyar
# Processing Record 1 of Set 16 | qasigiannguit
# Processing Record 2 of Set 16 | deputatskiy
# Processing Record 3 of Set 16 | san andres
# Processing Record 4 of Set 16 | deh rawud
# City not found. Skipping...
# Processing Record 5 of Set 16 | kondinskoye
# Processing Record 6 of Set 16 | saint anthony
# Processing Record 7 of Set 16 | pali
# Processing Record 8 of Set 16 | bouna
# Processing Record 9 of Set 16 | westport
# Processing Record 10 of Set 16 | gama
# Processing Record 11 of Set 16 | catia la mar
# Processing Record 12 of Set 16 | belmonte
# Processing Record 13 of Set 16 | beyneu
# Processing Record 14 of Set 16 | vanavara
# Processing Record 15 of Set 16 | bathsheba
# Processing Record 16 of Set 16 | oranjemund
# Processing Record 17 of Set 16 | nioro
# Processing Record 18 of Set 16 | mattru
# Processing Record 19 of Set 16 | muroto
# Processing Record 20 of Set 16 | bodden town
# Processing Record 21 of Set 16 | kokoda
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
pprint.pprint(city_weather)
# Out:
# {'base': 'stations',
#  'clouds': {'all': 68},
#  'cod': 200,
#  'coord': {'lat': -8.8785, 'lon': 147.7407},
#  'dt': 1648060821,
#  'id': 2093691,
#  'main': {'feels_like': 74.39,
#           'grnd_level': 971,
#           'humidity': 93,
#           'pressure': 1011,
#           'sea_level': 1011,
#           'temp': 73.02,
#           'temp_max': 73.02,
#           'temp_min': 73.02},
#  'name': 'Kokoda',
#  'sys': {'country': 'PG', 'sunrise': 1648066370, 'sunset': 1648109881},
#  'timezone': 36000,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 227, 'gust': 2.46, 'speed': 1.63}}

# %%
#Add the data to a list in a dictionary format and then convert the list to a DataFrame.
city_data_df = pd.DataFrame(city_data)


#Reorder columns as City, Country, Date, Lat, Lng, Max Temp, Humidity, Cloudiness, and Wind Speed
new_column_order = ["City","Country","Lat","Lng","Max Temp","Humidity", "Cloudiness","Wind Speed","Current Description"]

#assign city_data_df with new column order
city_data_df = city_data_df[new_column_order]

# Display DataFrame
city_data_df
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0          Thompson      CA  55.7435  -97.8558     32.16        80
# 1         Upernavik      GL  72.7868  -56.1549     -2.72        93
# 2        Dzerzhinsk      RU  56.2389   43.4631     39.02        52
# 3    Cabo San Lucas      MX  22.8909 -109.9124     85.60        37
# 4         Busselton      AU -33.6500  115.3333     56.03        81
# ..              ...     ...      ...       ...       ...       ...
# 708           Nioro      GM  13.3500  -15.7500     86.95        29
# 709          Mattru      SL   7.6244  -11.8332     83.37        66
# 710          Muroto      JP  33.2833  134.1500     51.67        77
# 711     Bodden Town      KY  19.2833  -81.2500     87.80        58
# 712          Kokoda      PG  -8.8785  147.7407     73.02        93
#
#      Cloudiness  Wind Speed Current Description
# 0           100        8.05     overcast clouds
# 1            87        2.80     overcast clouds
# 2             0        4.47           clear sky
# 3             0        3.44           clear sky
# 4             0       12.15           clear sky
# ..          ...         ...                 ...
# 708           4       12.86           clear sky
# 709          74        7.74       broken clouds
# 710          72        6.89       broken clouds
# 711          40       12.66    scattered clouds
# 712          68        1.63       broken clouds
#
# [713 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
